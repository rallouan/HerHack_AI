# %%
import pandas as pd

# %%
X = pd.read_csv('msr_paraphrase_data.txt', sep="\t", header=None)

# %%
print(X)
# Out:
#                 0  ...           6
# 0     Sentence ID  ...    Web Date
# 1          702876  ...  2003/06/04
# 2          702977  ...  2003/06/04
# 3         2108705  ...  2003/08/23
# 4         2108831  ...  2003/08/23
# ...           ...  ...         ...
# 5715       127940  ...  2003/05/07
# 5716       127709  ...  2003/05/07
# 5717       467443  ...  2003/05/23
# 5718       467517  ...  2003/05/23
# 5719      1489846  ...         NaN
#
# [5720 rows x 7 columns]

# %%
print(X[0])
# Out:
# 0       Sentence ID
# 1            702876
# 2            702977
# 3           2108705
# 4           2108831
#            ...
# 5715         127940
# 5716         127709
# 5717         467443
# 5718         467517
# 5719        1489846
# Name: 0, Length: 5720, dtype: object

# %%
print(X[1])
# Out:
# 0                                                  String
# 1       Amrozi accused his brother, whom he called "th...
# 2       Referring to him as only "the witness", Amrozi...
# 3       Yucaipa owned Dominick's before selling the ch...
# 4       Yucaipa bought Dominick's in 1995 for $693 mil...
#                               ...
# 5715    Manfred Bischoff, EADS co-chairman and also a ...
# 5716    Manfred Bischoff, EADS co-chairman and a membe...
# 5717    The TAAD and SAR-x chips are priced from $125 ...
# 5718    The products are priced at $575 and $295 in qu...
# 5719    The findings are being published today in the ...
# Name: 1, Length: 5720, dtype: object

# %%
print(X[2])
# Out:
# 0               Author
# 1       Darren Goodsir
# 2       Darren Goodsir
# 3        MICHAEL GIBBS
# 4           ALEX VEIGA
#              ...
# 5715        Kevin Done
# 5716        Kevin Done
# 5717    Michael Singer
# 5718       The Numbers
# 5719               NaN
# Name: 2, Length: 5720, dtype: object

# %%
print(X[3])
# Out:
# 0                              URL
# 1                www.theage.com.au
# 2                   www.smh.com.au
# 3                 www.nwherald.com
# 4                    www.miami.com
#                    ...
# 5715                   news.ft.com
# 5716                   news.ft.com
# 5717    siliconvalley.internet.com
# 5718                   rcrnews.com
# 5719                           NaN
# Name: 3, Length: 5720, dtype: object

# %%
print(X[4])
# Out:
# 0                      Agency
# 1                           *
# 2       Sydney Morning Herald
# 3                           *
# 4                           *
#                 ...
# 5715                        *
# 5716                        *
# 5717                        *
# 5718                        *
# 5719                      NaN
# Name: 4, Length: 5720, dtype: object

# %%
print(X[5])
# Out:
# 0               Date
# 1        June 5 2003
# 2        June 5 2003
# 3                  *
# 4                  *
#             ...
# 5715               *
# 5716               *
# 5717    May 23, 2003
# 5718               *
# 5719             NaN
# Name: 5, Length: 5720, dtype: object

# %%
print(X[6])
# Out:
# 0         Web Date
# 1       2003/06/04
# 2       2003/06/04
# 3       2003/08/23
# 4       2003/08/23
#            ...
# 5715    2003/05/07
# 5716    2003/05/07
# 5717    2003/05/23
# 5718    2003/05/23
# 5719           NaN
# Name: 6, Length: 5720, dtype: object

# %%
list(X.columns.values)
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
X = X.drop(6, 1)

# %%
print(X)
# Out:
#                 0  ...             5
# 0     Sentence ID  ...          Date
# 1          702876  ...   June 5 2003
# 2          702977  ...   June 5 2003
# 3         2108705  ...             *
# 4         2108831  ...             *
# ...           ...  ...           ...
# 5715       127940  ...             *
# 5716       127709  ...             *
# 5717       467443  ...  May 23, 2003
# 5718       467517  ...             *
# 5719      1489846  ...           NaN
#
# [5720 rows x 6 columns]

# %%
X = X.drop(5, 1)
X = X.drop(4, 1)
X = X.drop(3, 1)
X = X.drop(2, 1)
X = X.drop(0, 1)

# %%
print(X)
# Out:
#                                                       1
# 0                                                String
# 1     Amrozi accused his brother, whom he called "th...
# 2     Referring to him as only "the witness", Amrozi...
# 3     Yucaipa owned Dominick's before selling the ch...
# 4     Yucaipa bought Dominick's in 1995 for $693 mil...
# ...                                                 ...
# 5715  Manfred Bischoff, EADS co-chairman and also a ...
# 5716  Manfred Bischoff, EADS co-chairman and a membe...
# 5717  The TAAD and SAR-x chips are priced from $125 ...
# 5718  The products are priced at $575 and $295 in qu...
# 5719  The findings are being published today in the ...
#
# [5720 rows x 1 columns]

# %%
import numpy as np

# %%
np.savetxt(r'msr_paraphrase_data_edited.txt', X.values, fmt='%s')
