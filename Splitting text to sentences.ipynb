# %%
# !pip3 install nltk

# %%
import nltk
nltk.download('punkt')
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk import sent_tokenize
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktTrainer
from pprint import pprint

# %%
from nltk.corpus import gutenberg
 
text = ""
for file_id in gutenberg.fileids():
    text += gutenberg.raw(file_id)

# %%
trainer = PunktTrainer()
trainer.INCLUDE_ALL_COLLOCS = True
trainer.train(text)
 
tokenizer = PunktSentenceTokenizer(trainer.get_params())

# %%
sentences = "Mr. James told me aphet. Brown is not available today. I will try tomorrow."
 
print (tokenizer.tokenize(sentences))
# Out:
# ['Mr. James told me aphet.', 'Brown is not available today.', 'I will try tomorrow.']

# %%
print (tokenizer._params.abbrev_types)
# Out:
# {'sey', '1.ple', 'polon', 'm', 'boa', 'deci', 'hag', 'm.d', 'ave', 'ple', 'stra', 'mss', 'cass', 'por', 'amb', 'k', 'g', 'dut', 'malc', 'brut', 'clo', 'feb', 'vol', 'i.e', "'mr", 'trans', 'cin', 'mes', 'jun', 'osr', 'messa', 'ami', 'banq', 'ult', 'pol', 'lbs', 'syw', 'w', 'cic', "'w", 'len', 'hon', 'o.r', 'b', 'cai', 'j', 'lep', 'clit', 'mac', 'hec', 'y.sey', 'm.p', 'finsb', 'c', 'u', 'oct', 'n.e', 'ibid', "'dr", 'ara', 'g.k', 'ro', 'br', 'ely', 'gent', 'p', 'gen', 'k.c', 'poe', 'a.s', 'macb', 'wm', 'hora', 'v.e', 'cop', 'qu', 'mal', 'ser', 'fred', 'cyn', 's.w.f', 'ed', 'macd', 'phil', 'bru', 'moo', 'cath', 'dec', 'guil', 'sw', 'f', 'tit', 'foh', 'p.m', 'ophe', 'esq', 'burs', 'pind', 'p.s', 'luc', 'cas', 'p.h', 'cassi', 'bap', 'talb', 'rosin', 'cob', 'n', 'xx', 'rev', 'gho', 'mt', 'ros', 'ant', 'doct', 'dard', 'dag', 'ment', 'var', 'calp', 'prima', 'etc', 'l10', 'cly', 'laer', 'ang', 'a.d', 'xxx', 'ger', 'fran', 'vat', 'fla', 'u.s', 'treb', 'octa', 'mur'}

# %%
bruh= ['a','abbrev','Abbrev','Abd','Aberd','Aberdeensh','abl','Abol','Aborig','Abp','Abr','Abridg','Abridgem','absol','Absol','Abst','abstr','Abstr','Acad',
       'acc','Acc','Accept','Accomm','Accompl','Accs','Acct','Accts','accus','Achievem','A.D','ad','Add','Addit','Addr','adj','adjs','Adm','Admin','Admir',
       'Admon','Admonit','adv','Adv','Advancem','advb','Advert','Advoc','advs','Advt','Advts','Aerodynam','Aeronaut','Aff','Affect','Afr','Agric','agst','Alch',
       'Alg','Alleg','Allit','Alm','Alph','alt','Amer','Anal','Analyt','Anat','Anc','Anecd','Ang','Angl','Anglo-Ind','Anim','Ann','Anniv','Annot','Anon',
       'Answ','Ant','Anthrop','Anthropol','Antiq','aphet','Apoc','Apol','app','Appl','Applic','appos','Apr','Arab','Arb','arch','Arch','Archaeol',
       'Archipel','Archit','Argt','Arith','Arithm','Arrangem','art','Artic','Artific','Artill','Ashm','Assemb','Assoc','Assyriol','Astr','Astrol','Astron',
       'Astronaut','Att','attrib','Aug','Austral','Auth','Autobiog','Autobiogr','A.V','Ayrsh','Bacteriol','B.C','Bedford','Bedfordsh','bef','Bel & Dr','Belg',
       'Berks','Berksh','Berw','Berwicksh','betw','Bibliogr','Biochem','Biog','Biogr','Biol','Bk','Bks','BNC','Bord','Bot','Bp','Braz','Brit','Bucks','Build',
       'Bull','Bur','c','Cal','Calc','Calend','Calif','Calligr','Camb','Cambr','Campanol','Canad','Canterb','Capt','Cartogr','Catal','Catech','Cath',
       'cent','Ceram','Cert','Certif','cf','Ch','Chamb','Char','Charac','Chas','Chem. Engin','Chem','Chesh','Ch. Hist','Chr','Chron','Chronol','Chrons',
       'Cinematogr','Circ','Civ. Law','Civil Engin','cl','Class. Antiq','Classif','Climatol','Clin','cogn. w','Col','Coll','colloq','Coloss','Com','Comm',
       'Commandm','Commerc','Commiss','Comm. Law','Commonw','Communic','comp','Compan','Comp. Anat','compar','Compend','compl','Compos','conc','Conch',
       'Concl','concr','Conf','Confid','Confl','Confut','Congr','Congreg','Congress','conj','Conn','Consc','Consecr','Consid','Consol','const','Constit. Hist',
       'Constit','Constr','Contemp','Contempl','contempt','Contin','contr','Contrib','Controv','Conv','Conversat','Convoc','Cor','Cornw','Coron','Corr',
       'Corp','corresp','Counc','Courtsh','cpd','Craniol','Craniom','Crim','Crim. Law','Crit','Crt','Crts','Cryptogr','Crystallogr','Ct','Cumb','Cumberld',
       'Cumbld','Cycl','Cytol','Dan','dat','Dau','D.C','Deb','Dec','Declar','Ded','def','Deliv','dem','Demonstr','Dep','Depred','Depredat','Dept','Derbysh',
       'deriv','derog','Descr','Deut','Devonsh','Dict','Diffic','dim','Dis','Disc','Discipl','Discov','Discrim','Dist','Distemp','Distill','Distrib','Div',
       'Divers','Dk','Doc','Doctr','Domest','Durh','Dr','dyslog','e','E. Afr','E. Angl','E. Anglian','East Ind','Eccl','Eccles','Ecclus','Ecol','Econ','ed',
       'E.D.D','Edin','Edinb','Educ','Edw','E.E.T.S','Egyptol','E. Ind','Electr','Electr. Engin','Electro-magn','Electro-physiol','Elem','Eliz','Elizab',
       'ellipt','Emb','Embryol','e. midl','emph','Encycl','Encycl. Brit','Encycl. Metrop','Eng','Engin','Englishw','Enq','Ent','Enthus','Entom','Entomol',
       'Enzymol','eOE','Ep','Eph','Ephes','Epil','Episc','Epist','Epit','Equip','erron','Esd','esp','Ess','Essent','Establ','Esth','Ethnol','etym','etymol',
       'euphem','Eval','Evang','Evid','Evol','Ex. doc','Exalt','exc','Exch','Exec','Exerc','Exhib','Exod','Exper','Explan','Explic','Explor','Expos','Ezek',
       'exp','eg','f','Fab','fam','famil','Farew','Feb','fem','Ff','Fifesh','fig','fl','Footpr','Forfarsh','Fortif','Fortn','Found','Fr','Fragm','Fratern',
       'freq','Friendsh','Furnit','fut','Gal','Gard','Gastron','Gaz','Gd','gen','Geo','Geog','Geogr','Geol','Geom','Geomorphol','Ger','Glac','Glasg','Glos',
       'Gloss','Glouc','Gloucestersh','Gosp','Gov','Govt','Gr','Gram','Gramm. Analysis','Gt','Gynaecol','Hab','Haematol','Hag','Hampsh','Handbk','Hants',
       'Heb','Hebr','Hen','Heref','Hereford','Herefordsh','Hertfordsh','Hierogl','hist','Histol','Hom','Horol','Hort','Hos','Hosp','Househ','Housek','Husb',
       'Hydraul','Hydrol','Ichth','Icthyol','Ideol','Illustr','Imag','imit','Immunol','imp','imperf','impers','impf','Impr','improp','Inaug','Inclos','Inc',
       'ind','Ind','indef','indic','indir','Industr','Industr. Rel','infin','infl','Innoc','Inorg','Inq','Inst','instr','Instr','int','Intell','Interc',
       'interj','Interl','Internat','Interpr','interrog','intr','intrans','Intro','Introd','Inv','Invertebr','Invert. Zool','Investig','Investm','Invoc',
       'Ir','Irel','irreg','Isa','Ital','Jahrb','Jan','Jap','Jas','Jer','joc','Jrnl','Jrnls','Jud','Judg','Jul','Jun','Jurisd','Jurisdict','Jurispr',
       'Justif','Justific','K','Kent','Kgs','King’s Bench Div','Kingd','Knowl','Kpr','l','Lab','Lam','Lanc','Lancash','Lancs','Lang','Langs','Lat','Ld',
       'Lds','Lect','Leechd','Leg','Leicest','Leicester','Leicestersh','Leics','Let','Lett','Lev','Lex','Libr','Limnol','Lincolnsh','Lincs','Ling','Linn',
       'lit','Lithogr','Lithol','Liturg','ll','lOE','Lond','LXX','m','Macc','Mach','Mag','Magn','Mal','Man','Managem','Manch','Manip','Manuf','Mar','masc',
       'Mass','Math','Matt','Meas','Measurem','Mech','med','Med','Medit','Mem','Merc','Merch','Metallif','Metallogr','Metallogr','Metamorph','Metaph',
       'Meteorol','metr. gr','Metrop','Mex','Microbiol','Microsc','midl','Mil','Milit','Min','Misc','Miscell','mispr','mod','Monum','Morphol','MS','MSS',
       'Mt','Mtg','Mts','Munic','Munif','Munim','Mus','Myst','Msc','n','N. Afr','Nah','N. Amer','Narr','Narrat','Nat','Nat. Hist','Nat. Philos','Nat. Sci',
       'Naut','Nav','Navig','N. Carolina','N. Dakota','n.e','N.E','N.E.D','Neh','Neighb','Nerv','Neurol','Neurosurg','New Hampsh','Newc','Newspr','N. Ir',
       'N. Irel','No','nom','Non-conf','nonce-wd','Nonconf','Norf','?orthamptonsh','Northants','Northumb','Northumbld','Northumbr','Norw','Norweg','Notts',
       'Nov','ns','N.S. Wales','N.S.W','N.T','Nucl','Num','Numism','n.w','N.Y','N.Z','Obad','Obed','obj','obl','obs','Observ','Obstet','Obstetr',
       'Obstetr. Med','occas','Occup','Oceanogr','Oct','OE','O.E.D','Off','Offic','Okla','Ont','Ophthalm','Ophthalmol','opp','Opt','Orac','Ord','Org',
       'Organ. Chem','Org. Chem','orig','Orkn','Ornith','Ornithol','Orthogr','O.T','Outl','Oxf','Oxfordsh','Oxon','p','pa','Palaeobot','Palaeogr','Palaeont',
       'Palaeontol','pa. pple','Paraphr','Parasitol','Parl','Parnass','pass','pa. t','Pathol','Peculat','Penins','perf','perh','Periodontol','pers','Persec',
       'personif','Perthsh','Petrogr','pf','Pharm','Pharmaceut','Pharmacol','Philad','Philem','Philol','Philos','Phoen','phonet','Phonol','Photog','Photogr',
       'phr','Phrenol','Phys','Physical Chem','Physical Geogr','Physiogr','Physiol','Pict','pl','plur','Pol','Pol. Econ','Polit','Polytechn','Porc','poss',
       'Posth','Postm','Pott','ppl','pples','P. R','pr','Pract','prec','pred','predic','pref','Preh','Prehist','Prerog','pres','Presb','Preserv','pres. pple',
       'Prim','Princ','priv','prob','Probab','Probl','Proc','Prod','Prol','pron','pronunc','prop','propr','prov','Provid','Provinc','Provis','pr. pple','Ps',
       'pseudo-arch','pseudo-dial','pseudo Sc','Psych','Psychoanal','Psychoanalyt','Psychol','Psychopathol','Pt','Publ','Purg','Q','Q. Eliz','Qld',
       'Quantum Mech','Queen’s Bench Div','quot','quots','q.v','R','Radiol','R.A.F','R.C','Reas.Reb','Rebell','Rec','Recoll','Redempt','redupl','Ref',
       'refash','refl','Refus','Refut','reg','Regic','Regist','Regr','rel','Relig','Reminisc','Remonstr','Renfrewsh','Rep','repr','Reprod','Rept','Repub',
       'Res','Resid','Ret','Retrosp','Rev','Revol','Rhet','Rhode Isl','R.N','Rom','Rom. Antiq','Ross-sh','Roxb','Rudim','Russ','s','S. Afr','Sask','Sat',
       'Sax','sc','Scand','S. Carolina','Sch','Sci','Scot','Scotl','S. Dakota','s.e','Seismol','Sel','Sel. comm','Sept','Ser','Serm','Sess','Settlem',
       'Sev','Shaks','Sheph','Shetl','Shropsh','Soc','Sociol','Som','Sonn','sp','spec','Specs','Specif','Specim','Spectrosc','SS','St','Staffordsh',
       'Stat','Statist','Stock Exch','str','Stratigr','Struct','S.T.S','Stud','subj','subjunct','subord','subord. cl','Subscr','Subscript','subseq','subst',
       'suff','superl','Suppl','Supplic','Suppress','Surg','Surv','Sus','s.v','s.w','syll','Symmetr','Symp','Syst','t','Taxon','techn','Technol','Tel',
       'Telecomm','Telegr','Teleph','Teratol','Terminol','Terrestr','Textbk','Theat','Theatr','Theol','Theoret','Thermonucl','Thes','Thess','Tim','Topogr',
       'tr','Trad','Trag','trans','transf','transl','Transubstant','Trav','Treas','Treatm','Trib','Trig','Trigonom','Trop','Troub','Troubl','Typog','Typogr',
       'U.K','ult','Univ','unkn','Unnat','Unoffic','unstr','Urin','U.S','U.S.A.F','U.S.S.R','usu','Utilit','v','Va','Vac','var','varr','vars','vb','vbl',
       'vbl.n','vbl. ns','vbs','Veg','Veg. Phys','Veg. Physiol','Venet','Vertebr','Vet','Vet. Med','Vet. Path','Vet. Sci','Vet. Surg','Vic','Vict','Vind',
       'Vindic','Virg','Virol','viz','Voc','Vocab','Vol','Vols','Voy','v.r','v.rr','vulg','w','W. Afr','Warwicksh','wd','Westm','Westmld','Westmorld',
       'Westmrld','Wilts','Wiltsh','W. Ind','W. Indies','Wis','Wisd','wk','Wkly','Wks','Wonderf','Worc','Worcestersh','Worcs','Writ','W. Va','Yearbk',
       'Yng','Yorks','Yorksh','Yr','Yrs','Zech','Zeitschr','Zeph','Zoogeogr','Zool']
for x in bruh:
  tokenizer._params.abbrev_types.add(x)

# %%
print (tokenizer._params.abbrev_types)
# Out:
# {'prov', 'Rhet', 'Northumbld', 'Quantum Mech', 'Non-conf', 'Ashm', 'v.r', 'Confut', 'boa', 'Ser', 'Typogr', 'Westm', 'cogn. w', 'Astronaut', 'N.T', 'Topogr', 'a', 'Absol', 'Jahrb', 'vbl', 'priv', 'med', 'esp', 'obj', 'Psychoanal', 'Reprod', 'stra', 'Fab', 'Manuf', 'obs', 'Sociol', 'Worcestersh', 'N.E.D', 'g', 'Inst', 'Calligr', 'malc', 'Bedfordsh', 'Hereford', 'occas', 'Ref', 'Abp', 'Charac', 'Struct', 'King’s Bench Div', 'Evid', 'i.e', 'Bks', 'hist', 'pseudo-dial', 'Crim. Law', 'Bot', 'Jud', 'Coloss', 'Exerc', 'cin', 'Langs', 'Regist', 'alt', 'appos', 'Vols', 'messa', 'Berw', 'Leicestersh', 'Knowl', 'l', 'suff', 'Liturg', 'Wiltsh', 'Proc', 'cic', "'w", 'Vet. Surg', 'o.r', 'b', 'cai', 'Provinc', 'abl', 'Man', 'Englishw', 'Agric', 'Prehist', 'Hen', 'Offic', 'Handbk', 'Inq', 'U.K', 'Angl', 'Confl', 'Paraphr', 'Mag', 'Nov', 'Palaeobot', 'Myst', 'pers', 'instr', 'c', 'Observ', 'Staffordsh', 'Soc', 'oct', 'Zool', 'ibid', 'spec', 'U.S.S.R', 'Renfrewsh', 'Seismol', 'Trigonom', 'Ophthalmol',
# ...

# %%
print (tokenizer.tokenize(sentences))
# Out:
# ['Mr. James told me aphet. Brown is not available today.', 'I will try tomorrow.']
