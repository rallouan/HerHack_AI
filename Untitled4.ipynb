# %%
# !pip install django
# Out:
# ...
#      |████████████████████████████████| 7.9MB 7.9MB/s
# ...

# %%
# !PYTHON -m django --version
# Out:
# /bin/bash: PYTHON: command not found

# %%
# !pip install Django

# %%
! python -m django --version
# Out:
# 3.2.3

# %%
# !cd Example

# %%
# !django-admin startproject mysite
