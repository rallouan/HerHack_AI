# %%
# !git clone https://github.com/dair-iitd/CaRB
# Out:
# Cloning into 'CaRB'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 122 (delta 42), reused 105 (delta 29), pack-reused 0
# Receiving objects: 100% (122/122), 5.94 MiB | 8.13 MiB/s, done.
# Resolving deltas: 100% (42/42), done.

# %%
# %cd CaRB/
# Out:
# /content/CaRB

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 13.8MB 237kB/s
# ...
#      |████████████████████████████████| 1.1MB 59.3MB/s
# ...
#      |████████████████████████████████| 4.2MB 46.9MB/s
# ...
#      |████████████████████████████████| 8.3MB 18.3MB/s
# ...
#      |████████████████████████████████| 8.9MB 17.6MB/s
# ...
#      |████████████████████████████████| 42.5MB 1.6MB/s
# ...
#   Created wheel for ipdb: filename=ipdb-0.13.3-cp36-none-any.whl size=10847 sha256=a863bb71184516f8be6a8dc661df2cd7aa0ca437c0dbb0de5f3fcdd10c96c911
#   Stored in directory: /root/.cache/pip/wheels/75/00/30/4169bcc3643f0cf946dcf37af1b71364b390c4df91da02b03c
# ...
#   Created wheel for nltk: filename=nltk-3.2.1-cp36-none-any.whl size=1316642 sha256=d0a882c09c9f48c057b6c1fe054e654e99cf43a33e5c3dd1e85cd02a4587877b
#   Stored in directory: /root/.cache/pip/wheels/15/09/54/c7baf815a67c5f19ec23752715885b1ce25c9617e8a1c25da3
# ...
#   ERROR: Failed building wheel for numpy
#   Running setup.py clean for numpy
#   ERROR: Failed cleaning build dir for numpy
# ...

# %%
import nltk
nltk.download('stopwords')

# %%
# !python carb.py --gold=data/gold/test.tsv --out=dump/OpenIE-4.dat --openiefour=system_outputs/test/openie4_output.txt
