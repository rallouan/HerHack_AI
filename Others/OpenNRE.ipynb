# %%
# !git clone https://github.com/thunlp/OpenNRE.git --depth 1
# Out:
# Cloning into 'OpenNRE'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 62 (delta 14), reused 24 (delta 4), pack-reused 0
# Unpacking objects: 100% (62/62), done.

# %%
# %cd OpenNRE/
# Out:
# /content/OpenNRE

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch==1.6.0 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (1.6.0+cu101)
# Collecting transformers==3.0.2
#   Downloading https://files.pythonhosted.org/packages/27/3c/91ed8f5c4e7ef3227b4119200fc0ed4b4fd965b1f0172021c25701087825/transformers-3.0.2-py3-none-any.whl (769kB)
#      |████████████████████████████████| 778kB 4.4MB/s
# Collecting pytest==5.3.2
#   Downloading https://files.pythonhosted.org/packages/19/cf/711f1d887cb92c5155c9a1eb338f1b5d2411b50e4492a3b20e4a188a22b2/pytest-5.3.2-py3-none-any.whl (234kB)
#      |████████████████████████████████| 235kB 27.0MB/s
# Collecting scikit-learn==0.22.1
#   Downloading https://files.pythonhosted.org/packages/d1/48/e9fa9e252abcd1447eff6f9257636af31758a6e46fd5ce5d3c879f6907cb/scikit_learn-0.22.1-cp36-cp36m-manylinux1_x86_64.whl (7.0MB)
#      |████████████████████████████████| 7.1MB 17.0MB/s
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 5)) (1.4.1)
# Collecting nltk==3.4.5
#   Downloading https://files.pythonhosted.org/packages/f6/1d/d925cfb4f324ede997f6d47bea4d9babba51b49e87a767c170b77005889d/nltk-3.4.5.zip (1.5MB)
#      |████████████████████████████████| 1.5MB 46.2MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.6.0->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==1.6.0->-r requirements.txt (line 1)) (1.18.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers==3.0.2->-r requirements.txt (line 2)) (3.0.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers==3.0.2->-r requirements.txt (line 2)) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers==3.0.2->-r requirements.txt (line 2)) (4.41.1)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 35.9MB/s
# Collecting tokenizers==0.8.1.rc1
#   Downloading https://files.pythonhosted.org/packages/40/d0/30d5f8d221a0ed981a186c8eb986ce1c94e3a6e87f994eae9f4aa5250217/tokenizers-0.8.1rc1-cp36-cp36m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 37.5MB/s
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers==3.0.2->-r requirements.txt (line 2)) (0.7)
# Collecting sentencepiece!=0.1.92
#   Downloading https://files.pythonhosted.org/packages/d4/a4/d0a884c4300004a78cca907a6ff9a5e9fe4f090f5d95ab341c53d28cbc58/sentencepiece-0.1.91-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 33.4MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers==3.0.2->-r requirements.txt (line 2)) (20.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==3.0.2->-r requirements.txt (line 2)) (2019.12.20)
# Collecting pluggy<1.0,>=0.12
#   Downloading https://files.pythonhosted.org/packages/a0/28/85c7aa31b80d150b772fbe4a229487bc6644da9ccb7e427dd8cc60cb8a62/pluggy-0.13.1-py2.py3-none-any.whl
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pytest==5.3.2->-r requirements.txt (line 3)) (8.5.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from pytest==5.3.2->-r requirements.txt (line 3)) (0.2.5)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest==5.3.2->-r requirements.txt (line 3)) (20.2.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest==5.3.2->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: importlib-metadata>=0.12; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from pytest==5.3.2->-r requirements.txt (line 3)) (1.7.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn==0.22.1->-r requirements.txt (line 4)) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk==3.4.5->-r requirements.txt (line 6)) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.0.2->-r requirements.txt (line 2)) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.0.2->-r requirements.txt (line 2)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.0.2->-r requirements.txt (line 2)) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.0.2->-r requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.0.2->-r requirements.txt (line 2)) (7.1.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers==3.0.2->-r requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.12; python_version < "3.8"->pytest==5.3.2->-r requirements.txt (line 3)) (3.1.0)
# Building wheels for collected packages: nltk, sacremoses
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.4.5-cp36-none-any.whl size=1449906 sha256=8822db76b6663cc7608540a195e062e69b0e8921b683340d2ee461784b3d5b16
#   Stored in directory: /root/.cache/pip/wheels/96/86/f6/68ab24c23f207c0077381a5e3904b2815136b879538a24b483
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=ff0b225863718521062e8aec03a531a02d0c5771a7e83273f1d40e6dfefbede2
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built nltk sacremoses
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installing collected packages: sacremoses, tokenizers, sentencepiece, transformers, pluggy, pytest, scikit-learn, nltk
#   Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
#   Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# Successfully installed nltk-3.4.5 pluggy-0.13.1 pytest-5.3.2 sacremoses-0.0.43 scikit-learn-0.22.1 sentencepiece-0.1.91 tokenizers-0.8.1rc1 transformers-3.0.2

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating opennre.egg-info
# writing opennre.egg-info/PKG-INFO
# writing dependency_links to opennre.egg-info/dependency_links.txt
# writing top-level names to opennre.egg-info/top_level.txt
# writing manifest file 'opennre.egg-info/SOURCES.txt'
# writing manifest file 'opennre.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/opennre
# copying opennre/__init__.py -> build/lib/opennre
# copying opennre/pretrain.py -> build/lib/opennre
# creating build/lib/opennre/framework
# copying opennre/framework/utils.py -> build/lib/opennre/framework
# copying opennre/framework/data_loader.py -> build/lib/opennre/framework
# copying opennre/framework/__init__.py -> build/lib/opennre/framework
# copying opennre/framework/bag_re.py -> build/lib/opennre/framework
# copying opennre/framework/sentence_re.py -> build/lib/opennre/framework
# creating build/lib/opennre/module
# copying opennre/module/__init__.py -> build/lib/opennre/module
# creating build/lib/opennre/encoder
# copying opennre/encoder/cnn_encoder.py -> build/lib/opennre/encoder
# copying opennre/encoder/pcnn_encoder.py -> build/lib/opennre/encoder
# copying opennre/encoder/__init__.py -> build/lib/opennre/encoder
# copying opennre/encoder/base_encoder.py -> build/lib/opennre/encoder
# copying opennre/encoder/bert_encoder.py -> build/lib/opennre/encoder
# creating build/lib/opennre/tokenization
# copying opennre/tokenization/utils.py -> build/lib/opennre/tokenization
# copying opennre/tokenization/bert_tokenizer.py -> build/lib/opennre/tokenization
# copying opennre/tokenization/basic_tokenizer.py -> build/lib/opennre/tokenization
# copying opennre/tokenization/__init__.py -> build/lib/opennre/tokenization
# copying opennre/tokenization/word_tokenizer.py -> build/lib/opennre/tokenization
# copying opennre/tokenization/word_piece_tokenizer.py -> build/lib/opennre/tokenization
# creating build/lib/opennre/model
# copying opennre/model/bag_average.py -> build/lib/opennre/model
# copying opennre/model/base_model.py -> build/lib/opennre/model
# copying opennre/model/__init__.py -> build/lib/opennre/model
# copying opennre/model/softmax_nn.py -> build/lib/opennre/model
# copying opennre/model/bag_attention.py -> build/lib/opennre/model
# creating build/lib/opennre/module/pool
# copying opennre/module/pool/avg_pool.py -> build/lib/opennre/module/pool
# copying opennre/module/pool/__init__.py -> build/lib/opennre/module/pool
# copying opennre/module/pool/max_pool.py -> build/lib/opennre/module/pool
# creating build/lib/opennre/module/nn
# copying opennre/module/nn/cnn.py -> build/lib/opennre/module/nn
# copying opennre/module/nn/rnn.py -> build/lib/opennre/module/nn
# copying opennre/module/nn/lstm.py -> build/lib/opennre/module/nn
# copying opennre/module/nn/__init__.py -> build/lib/opennre/module/nn
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/opennre
# creating build/bdist.linux-x86_64/egg/opennre/framework
# copying build/lib/opennre/framework/utils.py -> build/bdist.linux-x86_64/egg/opennre/framework
# copying build/lib/opennre/framework/data_loader.py -> build/bdist.linux-x86_64/egg/opennre/framework
# copying build/lib/opennre/framework/__init__.py -> build/bdist.linux-x86_64/egg/opennre/framework
# copying build/lib/opennre/framework/bag_re.py -> build/bdist.linux-x86_64/egg/opennre/framework
# copying build/lib/opennre/framework/sentence_re.py -> build/bdist.linux-x86_64/egg/opennre/framework
# creating build/bdist.linux-x86_64/egg/opennre/module
# copying build/lib/opennre/module/__init__.py -> build/bdist.linux-x86_64/egg/opennre/module
# creating build/bdist.linux-x86_64/egg/opennre/module/pool
# copying build/lib/opennre/module/pool/avg_pool.py -> build/bdist.linux-x86_64/egg/opennre/module/pool
# copying build/lib/opennre/module/pool/__init__.py -> build/bdist.linux-x86_64/egg/opennre/module/pool
# copying build/lib/opennre/module/pool/max_pool.py -> build/bdist.linux-x86_64/egg/opennre/module/pool
# creating build/bdist.linux-x86_64/egg/opennre/module/nn
# copying build/lib/opennre/module/nn/cnn.py -> build/bdist.linux-x86_64/egg/opennre/module/nn
# copying build/lib/opennre/module/nn/rnn.py -> build/bdist.linux-x86_64/egg/opennre/module/nn
# copying build/lib/opennre/module/nn/lstm.py -> build/bdist.linux-x86_64/egg/opennre/module/nn
# copying build/lib/opennre/module/nn/__init__.py -> build/bdist.linux-x86_64/egg/opennre/module/nn
# creating build/bdist.linux-x86_64/egg/opennre/encoder
# copying build/lib/opennre/encoder/cnn_encoder.py -> build/bdist.linux-x86_64/egg/opennre/encoder
# copying build/lib/opennre/encoder/pcnn_encoder.py -> build/bdist.linux-x86_64/egg/opennre/encoder
# copying build/lib/opennre/encoder/__init__.py -> build/bdist.linux-x86_64/egg/opennre/encoder
# copying build/lib/opennre/encoder/base_encoder.py -> build/bdist.linux-x86_64/egg/opennre/encoder
# copying build/lib/opennre/encoder/bert_encoder.py -> build/bdist.linux-x86_64/egg/opennre/encoder
# creating build/bdist.linux-x86_64/egg/opennre/tokenization
# copying build/lib/opennre/tokenization/utils.py -> build/bdist.linux-x86_64/egg/opennre/tokenization
# copying build/lib/opennre/tokenization/bert_tokenizer.py -> build/bdist.linux-x86_64/egg/opennre/tokenization
# copying build/lib/opennre/tokenization/basic_tokenizer.py -> build/bdist.linux-x86_64/egg/opennre/tokenization
# copying build/lib/opennre/tokenization/__init__.py -> build/bdist.linux-x86_64/egg/opennre/tokenization
# copying build/lib/opennre/tokenization/word_tokenizer.py -> build/bdist.linux-x86_64/egg/opennre/tokenization
# copying build/lib/opennre/tokenization/word_piece_tokenizer.py -> build/bdist.linux-x86_64/egg/opennre/tokenization
# copying build/lib/opennre/__init__.py -> build/bdist.linux-x86_64/egg/opennre
# copying build/lib/opennre/pretrain.py -> build/bdist.linux-x86_64/egg/opennre
# creating build/bdist.linux-x86_64/egg/opennre/model
# copying build/lib/opennre/model/bag_average.py -> build/bdist.linux-x86_64/egg/opennre/model
# copying build/lib/opennre/model/base_model.py -> build/bdist.linux-x86_64/egg/opennre/model
# copying build/lib/opennre/model/__init__.py -> build/bdist.linux-x86_64/egg/opennre/model
# copying build/lib/opennre/model/softmax_nn.py -> build/bdist.linux-x86_64/egg/opennre/model
# copying build/lib/opennre/model/bag_attention.py -> build/bdist.linux-x86_64/egg/opennre/model
# byte-compiling build/bdist.linux-x86_64/egg/opennre/framework/utils.py to utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/framework/data_loader.py to data_loader.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/framework/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/framework/bag_re.py to bag_re.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/framework/sentence_re.py to sentence_re.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/module/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/module/pool/avg_pool.py to avg_pool.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/module/pool/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/module/pool/max_pool.py to max_pool.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/module/nn/cnn.py to cnn.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/module/nn/rnn.py to rnn.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/module/nn/lstm.py to lstm.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/module/nn/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/encoder/cnn_encoder.py to cnn_encoder.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/encoder/pcnn_encoder.py to pcnn_encoder.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/encoder/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/encoder/base_encoder.py to base_encoder.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/encoder/bert_encoder.py to bert_encoder.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/tokenization/utils.py to utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/tokenization/bert_tokenizer.py to bert_tokenizer.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/tokenization/basic_tokenizer.py to basic_tokenizer.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/tokenization/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/tokenization/word_tokenizer.py to word_tokenizer.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/tokenization/word_piece_tokenizer.py to word_piece_tokenizer.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/pretrain.py to pretrain.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/model/bag_average.py to bag_average.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/model/base_model.py to base_model.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/model/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/model/softmax_nn.py to softmax_nn.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/opennre/model/bag_attention.py to bag_attention.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying opennre.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying opennre.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying opennre.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying opennre.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/opennre-0.1-py3.6.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing opennre-0.1-py3.6.egg
# Copying opennre-0.1-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding opennre 0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/opennre-0.1-py3.6.egg
# Processing dependencies for opennre==0.1
# Finished processing dependencies for opennre==0.1

# %%
# !python setup.py develop
# Out:
# running develop
# running egg_info
# writing opennre.egg-info/PKG-INFO
# writing dependency_links to opennre.egg-info/dependency_links.txt
# writing top-level names to opennre.egg-info/top_level.txt
# writing manifest file 'opennre.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.6/dist-packages/opennre.egg-link (link to .)
# Removing opennre 0.1 from easy-install.pth file
# Adding opennre 0.1 to easy-install.pth file
#
# Installed /content/OpenNRE
# Processing dependencies for opennre==0.1
# Finished processing dependencies for opennre==0.1

# %%
# !bash benchmark/download_fewrel.sh
# Out:
# --2020-09-21 00:43:43--  https://thunlp.oss-cn-qingdao.aliyuncs.com/opennre/benchmark/fewrel/fewrel_train.txt
# Resolving thunlp.oss-cn-qingdao.aliyuncs.com (thunlp.oss-cn-qingdao.aliyuncs.com)... 47.104.38.189
# Connecting to thunlp.oss-cn-qingdao.aliyuncs.com (thunlp.oss-cn-qingdao.aliyuncs.com)|47.104.38.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16759417 (16M) [text/plain]
# Saving to: ‘fewrel/fewrel_train.txt’
#
# fewrel_train.txt    100%[===================>]  15.98M  5.40MB/s    in 3.0s
#
# 2020-09-21 00:43:47 (5.40 MB/s) - ‘fewrel/fewrel_train.txt’ saved [16759417/16759417]
#
# --2020-09-21 00:43:47--  https://thunlp.oss-cn-qingdao.aliyuncs.com/opennre/benchmark/fewrel/fewrel_train_rel2id.json
# Resolving thunlp.oss-cn-qingdao.aliyuncs.com (thunlp.oss-cn-qingdao.aliyuncs.com)... 47.104.38.189
# Connecting to thunlp.oss-cn-qingdao.aliyuncs.com (thunlp.oss-cn-qingdao.aliyuncs.com)|47.104.38.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 759 [application/json]
# Saving to: ‘fewrel/fewrel_train_rel2id.json’
#
# fewrel_train_rel2id 100%[===================>]     759  --.-KB/s    in 0s
#
# 2020-09-21 00:43:49 (99.4 MB/s) - ‘fewrel/fewrel_train_rel2id.json’ saved [759/759]
#
# --2020-09-21 00:43:49--  https://thunlp.oss-cn-qingdao.aliyuncs.com/opennre/benchmark/fewrel/fewrel_val.txt
# Resolving thunlp.oss-cn-qingdao.aliyuncs.com (thunlp.oss-cn-qingdao.aliyuncs.com)... 47.104.38.189
# Connecting to thunlp.oss-cn-qingdao.aliyuncs.com (thunlp.oss-cn-qingdao.aliyuncs.com)|47.104.38.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4155091 (4.0M) [text/plain]
# Saving to: ‘fewrel/fewrel_val.txt’
#
# fewrel_val.txt      100%[===================>]   3.96M  2.24MB/s    in 1.8s
#
# 2020-09-21 00:43:52 (2.24 MB/s) - ‘fewrel/fewrel_val.txt’ saved [4155091/4155091]
#
# --2020-09-21 00:43:52--  https://thunlp.oss-cn-qingdao.aliyuncs.com/opennre/benchmark/fewrel/fewrel_val_rel2id.json
# Resolving thunlp.oss-cn-qingdao.aliyuncs.com (thunlp.oss-cn-qingdao.aliyuncs.com)... 47.104.38.189
# Connecting to thunlp.oss-cn-qingdao.aliyuncs.com (thunlp.oss-cn-qingdao.aliyuncs.com)|47.104.38.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 179 [application/json]
# Saving to: ‘fewrel/fewrel_val_rel2id.json’
#
# fewrel_val_rel2id.j 100%[===================>]     179  --.-KB/s    in 0s
#
# 2020-09-21 00:43:54 (26.6 MB/s) - ‘fewrel/fewrel_val_rel2id.json’ saved [179/179]

# %%
import opennre
model = opennre.get_model('wiki80_bertentity_softmax')
# Out:
# 2020-09-21 01:16:49,829 - root - INFO - Loading BERT pre-trained checkpoint.
# 2020-09-21 01:16:49,831 - transformers.configuration_utils - INFO - loading configuration file /root/.opennre/pretrain/bert-base-uncased/config.json
# 2020-09-21 01:16:49,833 - transformers.configuration_utils - INFO - Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# 2020-09-21 01:16:49,834 - transformers.modeling_utils - INFO - loading weights file /root/.opennre/pretrain/bert-base-uncased/pytorch_model.bin
# 2020-09-21 01:16:52,503 - transformers.modeling_utils - INFO - All model checkpoint weights were used when initializing BertModel.
#
# 2020-09-21 01:16:52,504 - transformers.modeling_utils - INFO - All the weights of BertModel were initialized from the model checkpoint at /root/.opennre/pretrain/bert-base-uncased.
# If your task is similar to the task the model of the ckeckpoint was trained on, you can already use BertModel for predictions without further training.
# 2020-09-21 01:16:52,506 - transformers.tokenization_utils_base - INFO - Model name '/root/.opennre/pretrain/bert-base-uncased' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, TurkuNLP/bert-base-finnish-cased-v1, TurkuNLP/bert-base-finnish-uncased-v1, wietsedv/bert-base-dutch-cased). Assuming '/root/.opennre/pretrain/bert-base-uncased' is a path, a model identifier, or url to a directory containing tokenizer files.
# 2020-09-21 01:16:52,510 - transformers.tokenization_utils_base - INFO - Didn't find file /root/.opennre/pretrain/bert-base-uncased/added_tokens.json. We won't load it.
# 2020-09-21 01:16:52,511 - transformers.tokenization_utils_base - INFO - Didn't find file /root/.opennre/pretrain/bert-base-uncased/special_tokens_map.json. We won't load it.
# 2020-09-21 01:16:52,513 - transformers.tokenization_utils_base - INFO - Didn't find file /root/.opennre/pretrain/bert-base-uncased/tokenizer_config.json. We won't load it.
# 2020-09-21 01:16:52,514 - transformers.tokenization_utils_base - INFO - Didn't find file /root/.opennre/pretrain/bert-base-uncased/tokenizer.json. We won't load it.
# 2020-09-21 01:16:52,522 - transformers.tokenization_utils_base - INFO - loading file /root/.opennre/pretrain/bert-base-uncased/vocab.txt
# 2020-09-21 01:16:52,523 - transformers.tokenization_utils_base - INFO - loading file None
# 2020-09-21 01:16:52,524 - transformers.tokenization_utils_base - INFO - loading file None
# 2020-09-21 01:16:52,525 - transformers.tokenization_utils_base - INFO - loading file None
# 2020-09-21 01:16:52,529 - transformers.tokenization_utils_base - INFO - loading file None

# %%
model.infer({'text': 'He was the son of Máel Dúin mac Máele Fithrich, and grandson of the high king Áed Uaridnach (died 612).', 'h': {'pos': (18, 46)}, 't': {'pos': (78, 91)}})
# Out:
# ('father', 0.9927453398704529)
