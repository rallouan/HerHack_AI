# %%
# !pip install gpt-2-simple

import gpt_2_simple as gpt2
import os
import requests

model_name = "355M"
if not os.path.isdir(os.path.join("models", model_name)):
	print(f"Downloading {model_name} model...")
	gpt2.download_gpt2(model_name=model_name)   # model is saved into current directory under /models/124M/
# Out:
# Requirement already satisfied: gpt-2-simple in /usr/local/lib/python3.6/dist-packages (0.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (4.28.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (2.21.0)
# Requirement already satisfied: toposort in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (1.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (2019.12.20)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (1.17.5)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (2.8)
# Fetching checkpoint: 1.05Mit [00:00, 185Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 118Mit/s]
# Downloading 355M model...
# Fetching hparams.json: 1.05Mit [00:00, 197Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:10, 135Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 249Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 101Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 129Mit/s]

# %%
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:02<00:00,  2.26s/it]
# dataset has 338025 tokens
# Training...
# [1 | 127.36] loss=4.31 avg=4.31
# [2 | 243.70] loss=3.85 avg=4.08
# [3 | 359.63] loss=3.76 avg=3.97
# [4 | 474.72] loss=3.75 avg=3.91
# [5 | 590.41] loss=3.67 avg=3.86
# [6 | 706.14] loss=3.78 avg=3.85
# [7 | 821.41] loss=3.69 avg=3.83
# [8 | 934.24] loss=3.73 avg=3.81
# [9 | 1048.43] loss=3.53 avg=3.78
# [10 | 1163.33] loss=3.57 avg=3.76
# [11 | 1278.14] loss=3.79 avg=3.76
# [12 | 1392.95] loss=3.71 avg=3.76
# [13 | 1508.15] loss=3.71 avg=3.75
# [14 | 1623.21] loss=3.76 avg=3.75
# [15 | 1738.21] loss=3.57 avg=3.74
# [16 | 1852.82] loss=3.55 avg=3.73
# [17 | 1967.48] loss=3.66 avg=3.72
# [18 | 2082.90] loss=3.47 avg=3.71
# [19 | 2198.16] loss=3.43 avg=3.69
# [20 | 2313.47] loss=3.51 avg=3.68
# [21 | 2429.52] loss=3.30 avg=3.66
# [22 | 2545.30] loss=3.43 avg=3.65
# [23 | 2661.23] loss=3.43 avg=3.64
# [24 | 2777.33] loss=3.20 avg=3.62
# [25 | 2893.29] loss=3.57 avg=3.62
# [26 | 3009.63] loss=3.46 avg=3.61
# [27 | 3126.05] loss=3.46 avg=3.60
# [28 | 3242.55] loss=3.49 avg=3.60
# [29 | 3359.07] loss=3.43 avg=3.59
# [30 | 3474.81] loss=3.58 avg=3.59
# [31 | 3589.90] loss=3.49 avg=3.59
# [32 | 3705.02] loss=3.37 avg=3.58
# [33 | 3820.61] loss=3.50 avg=3.58
# [34 | 3937.19] loss=3.36 avg=3.57
# [35 | 4052.25] loss=3.57 avg=3.57
# [36 | 4168.12] loss=3.54 avg=3.57
# [37 | 4283.84] loss=3.33 avg=3.56
# [38 | 4399.58] loss=3.14 avg=3.55
# [39 | 4517.08] loss=3.48 avg=3.55
# [40 | 4632.74] loss=3.39 avg=3.54
# [41 | 4747.73] loss=3.25 avg=3.53
# [42 | 4863.16] loss=3.35 avg=3.53
# [43 | 4978.41] loss=3.50 avg=3.53
# [44 | 5095.15] loss=3.19 avg=3.52
# [45 | 5212.80] loss=3.26 avg=3.51
# [46 | 5328.93] loss=3.42 avg=3.51
# [47 | 5445.12] loss=3.58 avg=3.51
# [48 | 5561.16] loss=3.39 avg=3.51
# [49 | 5676.61] loss=3.44 avg=3.50
# [50 | 5792.79] loss=3.28 avg=3.50
# [51 | 5908.71] loss=3.41 avg=3.50
# [52 | 6024.40] loss=3.53 avg=3.50
# [53 | 6141.35] loss=3.32 avg=3.49
# [54 | 6257.70] loss=3.35 avg=3.49
# [55 | 6373.50] loss=3.20 avg=3.48
# [56 | 6488.65] loss=3.38 avg=3.48
# [57 | 6604.11] loss=3.21 avg=3.47
# [58 | 6719.41] loss=3.34 avg=3.47
# [59 | 6835.19] loss=3.25 avg=3.47
# [60 | 6950.91] loss=3.31 avg=3.46
# [61 | 7066.76] loss=3.23 avg=3.46
# [62 | 7182.27] loss=3.17 avg=3.45
# [63 | 7298.02] loss=3.18 avg=3.45
# [64 | 7413.09] loss=3.18 avg=3.44
# [65 | 7528.96] loss=3.30 avg=3.44
# [66 | 7644.72] loss=3.20 avg=3.43
# [67 | 7761.18] loss=3.27 avg=3.43
# [68 | 7877.83] loss=3.22 avg=3.42
# [69 | 7994.21] loss=3.03 avg=3.42
# [70 | 8110.51] loss=3.21 avg=3.41
# [71 | 8226.87] loss=3.22 avg=3.41
# [72 | 8343.13] loss=3.19 avg=3.40
# [73 | 8459.09] loss=3.19 avg=3.40
# [74 | 8574.71] loss=3.15 avg=3.40
# [75 | 8691.52] loss=3.11 avg=3.39
# [76 | 8807.42] loss=3.17 avg=3.39
# [77 | 8923.31] loss=3.40 avg=3.39
# [78 | 9039.01] loss=3.29 avg=3.38
# [79 | 9154.42] loss=3.27 avg=3.38
# [80 | 9270.24] loss=3.24 avg=3.38
# [81 | 9386.09] loss=3.40 avg=3.38
# [82 | 9501.90] loss=3.03 avg=3.37
# [83 | 9618.73] loss=3.23 avg=3.37
# [84 | 9734.89] loss=3.28 avg=3.37
# [85 | 9851.75] loss=3.41 avg=3.37
# [86 | 9967.98] loss=3.25 avg=3.37
# [87 | 10084.81] loss=3.08 avg=3.36
# [88 | 10200.63] loss=3.26 avg=3.36
# [89 | 10316.84] loss=3.17 avg=3.36
# [90 | 10432.88] loss=3.27 avg=3.36
# [91 | 10549.71] loss=3.32 avg=3.36
# [92 | 10665.62] loss=3.37 avg=3.36
# [93 | 10781.89] loss=3.14 avg=3.35
# [94 | 10898.43] loss=3.09 avg=3.35
# [95 | 11014.11] loss=3.05 avg=3.34
# [96 | 11130.36] loss=3.10 avg=3.34
# [97 | 11246.51] loss=3.09 avg=3.34
# [98 | 11362.66] loss=3.15 avg=3.33
# [99 | 11479.52] loss=3.27 avg=3.33
# [100 | 11595.49] loss=3.07 avg=3.33
