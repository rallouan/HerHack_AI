# %% [markdown]
# # Step 1
# Import TensorFlow and everything else you need

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# TensorFlow 1.x selected.
#   Building wheel for gpt-2-simple (setup.py) ... done
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
gpt2.download_gpt2(model_name="355M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 462Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 87.4Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 396Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:07, 195Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 350Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 135Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 193Mit/s]

# %%
# %cd drive
# %cd My Drive
# %cd Paraphrase
# Out:
# [Errno 2] No such file or directory: 'drive'
# /content/drive
# /content/drive/My Drive
# /content/drive/My Drive/Paraphrase

# %%
file_name = "msr_paraphrase_data.txt"

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name,
              model_name='355M',
              steps=1000,
              restore_from='fresh',
              run_name='run_2',
              print_every=100,
              sample_every=200,
              save_every=100
              )
gpt2.copy_checkpoint_to_gdrive(run_name='paraphrase1')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/355M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/355M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:02<00:00,  2.33s/it]
# dataset has 315908 tokens
# Training...
# [10 | 41.28] loss=2.82 avg=2.82
# [20 | 72.45] loss=2.45 avg=2.63
# [30 | 103.55] loss=1.99 avg=2.42
# [40 | 134.59] loss=2.09 avg=2.33
# [50 | 165.66] loss=2.16 avg=2.30
# [60 | 196.71] loss=1.71 avg=2.20
# [70 | 227.78] loss=1.95 avg=2.16
# [80 | 258.82] loss=2.03 avg=2.14
# [90 | 289.85] loss=1.98 avg=2.13
# [100 | 320.91] loss=1.79 avg=2.09
# [110 | 351.97] loss=1.63 avg=2.05
# [120 | 382.95] loss=1.95 avg=2.04
# [130 | 413.95] loss=1.74 avg=2.01
# [140 | 445.01] loss=1.88 avg=2.00
# [150 | 476.02] loss=2.04 avg=2.01
# [160 | 507.04] loss=1.82 avg=1.99
# [170 | 538.06] loss=1.24 avg=1.95
# [180 | 569.11] loss=1.84 avg=1.94
# [190 | 600.18] loss=1.42 avg=1.91
# [200 | 631.24] loss=1.80 avg=1.90
# Saving checkpoint/run1/model-200
# ======== SAMPLE 1 ========
#  is still being implemented to allow the public to share images, videos, music files and audio files.	BARBARA NICK	www.azcentral.com	*	July 7, 2003	2003/07/10
# 192567	The company has also announced its new products: "Sonic 2" and "Sonic the Hedgehog."	DAVID HANCOCK	www.nhl.com	*	*	2003/05/05
# 192685	Sonic 2 will be an enhanced version of Sonic The Hedgehog with enhanced graphics and voice chat capabilities.	JOHN RUBY HOFFMAN	www.thestar.com	*	*	2003/05/05
# 148566	"I'd probably say my worst experience was living with him," she said moments before she was arrested.	LISA FERRIER and PAUL CARLSONwww.nytimes.com	New York Times	July 10, 2003	2003/07/10
# 1512071	She said that her worst experience was living with him.	Paul Cole and Andrew Tully	www.newsday.com	*	Jul 11, 2003	2003/07/10
# 22222212	The company says the deal will combine its business of selling, distributing, and storing DVD and Blu-ray discs with its existing DVD, CDs, DVDs, and Blu-ray business.	Jim Taylor and John Walsh	www.canadapleywires.com	*	May 7, 2003	2003/05/07
# 222217	The move comes at the end of a busy time in the technology sector where the company says it expects to continue to reap value from DVD, Blu-ray and other DVD business lines.	Dennis Loomis	www.techweb.com	*	*	2003/05/07
# 1539071	Mr. Tene is no longer expected to return to the government, but senior government officials told Al Jazeera the governor's role still needed to be explained.	John Whitesides and Ben Kirby	www.cbc.ca	*	*	2003/05/06
# 1539019	Tene's government has not been expected to return to power, but senior government officials, speaking to Al Jazeera, say the governor's role still needed to be explained.	BRENDAN McINTOSH and KIRK-SUSAN COX	www.canada.com	*	*	2003/05/06
# 222586	"I think it is an outrage that they are allowed to shoot in a crowded movie theatre," James said.	Paul Revere	www.sun-sentinel.news.com.au	*	Jun 24 2003	2003/06/25
# 222740	"I think it is an outrage that they are allowed to shoot in a packed theater," Mr. James said at the screening.	SARA GARNAGE	www.globeandmail.com	*	*	2003/06/25
# 356522	"Now, I know of no one who has run under this bridge, but if you had to choose one bridge, which do you choose?" asked Richard Tarrant, 71, echoing a question from the audience in a suburban Denver diner.	GEOFF STEVENSON	www.signonsandiego.com	*	May 29, 2003	2003/05/30
# 356649	In a suburban diner in suburban Denver, 76-year-old retired Navy Admiral Richard Tarrant asked, "Now, I know of that bridge, which do you choose?"	John Stilko and Stephen Whitehouse	www.boston.com	*	*	2003/05/29
# 2520556	At a press conference in London on Monday, British Foreign Secretary Jack Straw and his Jordanian counterpart, Sheikh Osama al-Assiri, said Saddam Hussein would be punished for using poison gas in the Iraqi cities of Halabja and Fallujah.	BRIAN HARRINGTON	www.smh.com.au	Sydney Morning Herald	June 1, 2003	2003/06/01
# 25209082	The US delegation said that British Foreign Secretary Jack Straw and Jordan's foreign minister did not plan to issue a statement of condemnation.	JAMES WATSON and PAUL ELLIOTT	www.thesun.co.uk	*	June 1, 2003	2003/06/01
# 111225	The price was about 14 percent lower than a year ago, he said.	DAVID GRANIK	cbs.marketwatch.com	*	*	2003/09/14
# 111253	When he sold his stake in the company, the Dow Jones industrial average gained 0.4 percent, while the Nasdaq composite Index gained 0.2 percent.	David
#
# [210 | 710.29] loss=1.59 avg=1.89
# [220 | 741.39] loss=1.89 avg=1.89
# [230 | 772.48] loss=1.81 avg=1.88
# [240 | 803.57] loss=1.76 avg=1.88
# [250 | 834.68] loss=1.29 avg=1.85
# [260 | 865.73] loss=1.65 avg=1.84
# [270 | 896.85] loss=1.79 avg=1.84
# [280 | 927.92] loss=1.31 avg=1.82
# [290 | 959.00] loss=1.43 avg=1.80
# [300 | 990.09] loss=1.40 avg=1.79
# [310 | 1021.15] loss=1.60 avg=1.78
# [320 | 1052.14] loss=1.36 avg=1.77
# [330 | 1083.17] loss=1.44 avg=1.75
# [340 | 1114.22] loss=1.36 avg=1.74
# [350 | 1145.29] loss=0.83 avg=1.71
# [360 | 1176.35] loss=1.38 avg=1.70
# [370 | 1207.40] loss=1.02 avg=1.68
# [380 | 1238.45] loss=1.75 avg=1.68
# [390 | 1269.57] loss=1.71 avg=1.68
# [400 | 1300.68] loss=1.15 avg=1.66
# Saving checkpoint/run1/model-400
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# ======== SAMPLE 1 ========
# 	www.nynewsday.com	*	August 31, 2003	2003/08/31
# 257588	Cisco shares rose $3.96, or 5.8%, to $19.35 in morning trade before having gained $1.74.	Eric Burroughs	cbs.marketwatch.com	*	*	2003/10/07
# 257533	Cisco shares rebounded $4.94, or 9.4%, to $19.26.	Wim Wenders	reuters.com	Reuters	*	2003/10/07
# 276968	"We don't know whether any of our employees were involved in that," said Michael Geyer, a lawyer handling the antitrust case for Zuccarini.	Sally Kestin and Howard Pankratz	www.signonsandiego.com	*	*	2003/10/15
# 278702	"We don't know whether any of our employees were involved in that," said Michael Geyer, lawyer representing Zuccarini.	Sally Kestin Krasny	www.bayarea.com	*	*	2003/10/15
# 132706	Sterling fell sharply to a record high against the dollar in a surprise move on the Tokyo Stock Exchange yesterday.	Barbara Darrow	reuters.com	Reuters	*	2003/05/06
# 132737	The dollar fell sharply to a record high at ¥100.53 per dollar on the Tokyo Stock Exchange.	Barbara Darrow	reuters.com	Reuters	*	2003/05/06
# 275728	The U.S. Department of Justice filed its new "revised and extended privacy report" yesterday.	Karen Lohse	www.boston.com	*	*	2003/05/07
# 275731	The report was issued yesterday by the Justice Department's Computer Crimes Unit.	Karen Lohse	www.boston.com	*	*	2003/05/07
# 1906318	"What is particularly sad is that Congress created the Consumer Protection Act but did not pass the bill authorizing the program," he said.	Maggie Fox	www.courier-journal.com	*	August 20, 2003	2003/08/21
# 1906336	He said Congress created the Consumer Protection Act to protect consumers and was "willing to make exceptions" if consumers were harmed.	Maggie Fox	www.bayarea.com	*	*	2003/08/21
# 117798	The Dow Jones Industrial Average rose 15.78, or 0.5 per cent, at 1,050.91.	Kathy Griffin	seattletimes.nwsource.com	*	*	2003/06/13
# 117796	The Dow Jones Industrial Average .DJI climbed 24.05 points, or 0.4 per cent, at 1,050.11 points, marking the second-fastest weekly rise since January.	Kathy Griffin	reuters.com	Reuters	*	2003/06/13
# 566878	Coca-Cola Co. (nyse: KO.N), the world's most-popular soda maker, jumped 33.5 per cent for the session, while PepsiCo Inc. PEP.N gained 20.3 per cent for the period.	DAVID STOUT	*	Reuters	*	2003/05/05
# 565885	Coca-Cola Co. (nyse: PepsiCo.N), the world's most-popular soda maker, jumped 33.4 per cent for the session, while PepsiCo Inc. PEP.N climbed 20.3 percent for the period.	DAVID STOUT	*	Reuters	*	2003/05/05
# 1617889	The report said it was possible that the two could not detect him - although they could both smell his scent.	MARCIA ZUCHMANO	www.kansascity.com	*	*	2003/07/13
# 1671456	In an earlier test, a doctor confirmed that both the patient and his fiancee could detect him.	Caroline A. Sacco	reuters.com	Reuters	*	2003/07/03
# 1671488	The couple could both smell the other's scent and both could see him.	Caroline A. Sacco	asia.reuters.com	Reuters	*	2003/07/03
# 1456212	"My mind was up after the bat," Delgado said in a news conference on Wednesday, according to the Palm Beach Post.	Steve Grubel	www.sun-sentinel.com	*	*	2003/07/08
# 1456203	My mind was up after the
#
# [410 | 1375.54] loss=1.75 avg=1.67
# [420 | 1406.62] loss=1.68 avg=1.67
# [430 | 1437.76] loss=1.80 avg=1.67
# [440 | 1468.82] loss=0.86 avg=1.65
# [450 | 1499.87] loss=1.16 avg=1.63
# [460 | 1530.92] loss=1.40 avg=1.63
# [470 | 1561.98] loss=1.45 avg=1.62
# [480 | 1593.07] loss=1.13 avg=1.61
# [490 | 1624.15] loss=1.05 avg=1.60
# [500 | 1655.21] loss=1.09 avg=1.58
# [510 | 1686.24] loss=1.37 avg=1.58
# [520 | 1717.29] loss=0.96 avg=1.56
# [530 | 1748.37] loss=0.56 avg=1.54
# [540 | 1779.45] loss=1.66 avg=1.54
# [550 | 1810.53] loss=1.31 avg=1.54
# [560 | 1841.60] loss=1.50 avg=1.54
# [570 | 1872.66] loss=0.99 avg=1.52
# [580 | 1903.72] loss=1.11 avg=1.51
# [590 | 1934.78] loss=0.95 avg=1.50
# [600 | 1965.87] loss=1.72 avg=1.51
# Saving checkpoint/run1/model-600
# ======== SAMPLE 1 ========
# .com	*	*	2003/06/12
# 1867892	"We're determined to find a way to end this war, which will not be contained," Bush said.	JENNIFER O'NEIL	www.sun-sentinel.com	*	*	2003/07/21
# 1867897	"We're determined to find a way to end this war," Mr. Bush said as soldiers cleared the eastern city of Benghazi.	PETER ENAV	www.nytimes.com	New York Times	*	2003/07/21
# 2198629	This is a growing number of cases," said Dr. Bruce Johnson, commissioner of the Massachusetts Department of Public Health.	Vivian Chu	www.signonsandiego.com	*	June 21, 2003	2003/06/22
# 2127956	Johnson said this is a growing number of cases, which health officials are trying to treat.	Vivian Chu	www.signonsandiego.com	*	June 21, 2003	2003/06/22
# 2448576	The legislation, called the Medicare Security Act of 2003, was introduced by Rep. George Miller of California and is expected to pass the House on Tuesday.	Chris Mooney	news.mysanantonio.com	*	*	2003/09/25
# 2447937	The legislation, called the Medicare Security Act of 2003, was introduced by Rep. George Miller of California and is expected to pass the House on Tuesday.	Chris Mooney	news.mysanantonio.com	*	*	2003/09/25
# 205586	The broad Standard & Poor's 500 Index <.SPX> edged down 36 points, or 1.6 percent, to 927.	Denise Duclaux	www.forbes.com	*	*	2003/05/05
# 2055742	The Standard & Poor's 500 Index shed 0.5 percent, or a one-month slide, to 928.	Denise Duclaux	reuters.com	Reuters	*	2003/05/05
# 2100854	"It's still too early to know whether these new findings will pan out for a longer than expected stay," CDC director Dr. Tom Frieden said.	TOM HAYS	www.theledger.com	*	*	2003/08/28
# 2100858	"It is still too early to know whether these new findings will pan out for a longer than expected stay," Frieden said in a statement.	Mike Carter	wvgazette.com	*	August 27, 2003	2003/08/28
# 127779	It was first announced that the two would be meeting jointly on Thursday in Beijing to sign the new security treaty.	Mark Turner	washingtontimes.com	*	November 22, 2003	2003/11/23
# 127680	Holland will meet Iran's foreign minister in Beijing on Friday, and both will meet their American counterparts on Monday.	Mike Carter	wvgazette.com	*	November 23, 2003	2003/11/23
# 1659655	The attack came two days after a pair of suicide bombings in central Kabul that killed at least 18 people.	Harjit Sattar and Walid Moghadam	reuters.com	Reuters	*	2003/07/13
# 1659634	The attack came two days after a pair of suicide bombings in central Kabul that killed at least 18.	Harjit Sattar and Walid Moghadam	reuters.com	Reuters	*	2003/07/13
# 2748344	There was no indication whether the two new infections were new versions of the same diseases with different names.	Edward Simpkins	www.signonsandiego.com	*	October 29, 2003	2003/10/27
# 2746236	He said no new infections were identified, and that no new versions of the same diseases were identified.	Andrew Gans	reuters.com	Reuters	*	2003/10/27
# 1689472	Microsoft is working on a product update for customers who want to get rid of the Service Restriction List.	Chris Kraeuter	www.theregister.co.uk	*	*	2003/07/09
# 1689374	That's Microsoft's version of the Service Restriction List: A list of restrictions on information services that applies to specific types of Internet content.	Eric Chabrow	news.ft.com	*	*	2003/07/09
# 2608338	The report estimates that 25 percent of the population aged 18 or older has some form of severe retardation.	Maribel Espinoza	www.alertnet.org	*	*
#
# [610 | 2041.46] loss=1.32 avg=1.50
# [620 | 2072.71] loss=1.03 avg=1.49
# [630 | 2103.95] loss=0.91 avg=1.48
# [640 | 2135.17] loss=0.63 avg=1.46
# [650 | 2166.45] loss=2.01 avg=1.47
# [660 | 2197.69] loss=0.97 avg=1.46
# [670 | 2228.91] loss=1.08 avg=1.46
# [680 | 2260.18] loss=1.07 avg=1.45
# [690 | 2291.41] loss=1.33 avg=1.45
# [700 | 2322.60] loss=0.53 avg=1.43
# [710 | 2353.83] loss=1.10 avg=1.42
# [720 | 2385.04] loss=1.16 avg=1.42
# [730 | 2416.28] loss=0.91 avg=1.41
# [740 | 2447.53] loss=0.65 avg=1.39
# [750 | 2478.74] loss=1.45 avg=1.39
# [760 | 2509.94] loss=0.81 avg=1.38
# [770 | 2541.16] loss=0.50 avg=1.37
# [780 | 2572.44] loss=0.59 avg=1.35
# [790 | 2603.71] loss=1.13 avg=1.35
# [800 | 2634.97] loss=0.50 avg=1.33
# Saving checkpoint/run1/model-800
# ======== SAMPLE 1 ========
# 2003/11/20
# 2811781	Cubs outfielder Sammy Sosa, who became the second player in as many games Sunday to hit a home run, is the NL's leading hitter with a .545 on-base percentage.	Dennis Waszak III RandomRedditorwww.sltrib.com	*	Nov. 03, 2003	2003/11/03
# 510919	His daughter, Nina Axelrod, confirmed that he had died.	PAUL RECER	*	*	May 7, 2003	2003/05/29
# 518096	He has two daughters, Nina Axelrod and Robin, sister Nina Doss and aunt Nina Doss.	MAY WATERS	*	*	*	2003/05/29
# 1320353	A few hundred protesters swamped the court grounds on either side, but both sides largely ignored the standoff.	PATRICK HOWE	www.guardian.co.uk	*	*	2003/06/26
# 1320355	Protesters swamped the court site on either side, and neither side seemed to care.	PATRICK HOWE	www.ajc.com	The Atlanta Journal-Constitution	*	2003/06/26
# 341824	The company said the software is used to validate information provided by third-party supply chains and to provide cost-effective information to businesses seeking to sell goods from the United States.	Marilyn Geewax	straitstimes.asia1.com.sg	*	*	2003/05/06
# 341871	The company said the software is used in the validation of information provided by third-party supply chains and to give cost-effective information to businesses seeking to sell goods from the United States.	Marilyn Geewax	strikingtheplanet.com.sg	*	May 6, 2003	2003/05/06
# 1745772	Some 21.5 per cent of women who took a placebo taken the bioequivalency drug oestrogen plus progestin while 5.6 per cent took drospirenone.	Liz Vaughan and John Churchills	www.canada.com	*	July 22, 2003	2003/07/22
# 1754519	The researchers found that 11.5 per cent of the women taking bioequivalency pill took drospirenone, compared with 5.6 per cent who took a placebo.	Liz Vaughan and John Churchills	www.canada.com	*	July 22, 2003	2003/07/22
# 1020286	Federal regulators are investigating whether a faulty sprinkler system at a suburban Atlanta fire station caused a house fire that destroyed two sisters' apartment.	STEPHEN COWELL	www.thestar.com	*	*	2003/06/19
# 1020846	Federal investigators are looking into whether a faulty sprinkler system at a suburban fire station caused the sisters' apartment fire.	STEPHEN COWELL	www.kansascity.com	*	*	2003/06/19
# 2383202	In March 2000, the agency charged a former Georgia Tech assistant football coach, DeShaun Watson, with leaving troops without proper uniforms.	R. Bliss�www.boston.com	*	*	2003/09/06
# 2353547	Earlier this year, the Pentagon charged Watson, a former quarterback for the Atlanta Falcons who has played two seasons in the NFL.	John Hendren	www.boston.com	*	*	2003/09/06
# 919966	Preliminary approval has been granted for a second and final wave of industrial robots to reach the United States.	Andrew Wheeler	news.ft.com	*	*	2003/06/12
# 920036	The use of advanced robotics is being allowed for the first and final waves before the robots reach the United States.	James Maguire	news.independent.co.uk	*	*	2003/06/12
# 18095145	U.S. authorities have reported a resurgence of panic attacks in parts of the Philippines, part of the Western Philippines archipelago, following the enactment of a new law permitting the military to carry out extra-judiciary executions.	RODOLPH BHELVIERE	www.guardian.co.uk	*	*	2003/07/29
# 1809475	In part of the Philippines, panic attacks have returned following the enactment of a new law allowing the military to carry out extra-judicial executions.	Jimmy Burch	www.boston.com	*	*	2003/07/29
# 764980	After months of negotiations, representatives of Kurdish groups broke off negotiations after Baghdad refused to abandon its demand that they form a regional government in Iraq.	Katherine
#
# [810 | 2713.38] loss=0.83 avg=1.32
# [820 | 2744.65] loss=1.28 avg=1.32
# [830 | 2775.90] loss=0.92 avg=1.31
# [840 | 2807.12] loss=1.39 avg=1.32
# [850 | 2838.32] loss=0.50 avg=1.30
# [860 | 2869.53] loss=1.48 avg=1.30
# [870 | 2900.78] loss=0.69 avg=1.29
# [880 | 2932.05] loss=1.06 avg=1.29
# [890 | 2963.26] loss=0.66 avg=1.28
